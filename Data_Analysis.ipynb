# %%
# Importing libraries

import numpy as np
import pandas as pd

# %%
# Initial assessment of the Data

df = pd.read_csv(r"/home/fungazi/Projects/DroidF_actory/EntraID Triaging/SigninLogs_90d_520users.csv")
df.head()
# Out:
#                             AADTenantId  \
# 0  c0de1eb4-2763-451d-bf14-0f449a530ef9
# 1  c0de1eb4-2763-451d-bf14-0f449a530ef9
# 2  c0de1eb4-2763-451d-bf14-0f449a530ef9
# 3  c0de1eb4-2763-451d-bf14-0f449a530ef9
# 4  c0de1eb4-2763-451d-bf14-0f449a530ef9
#
#                                            Agent  \
# 0  {"agentType":"notAgentic","parentAppId":null}
# 1  {"agentType":"notAgentic","parentAppId":null}
# 2  {"agentType":"notAgentic","parentAppId":null}
# 3  {"agentType":"notAgentic","parentAppId":null}
# 4  {"agentType":"notAgentic","parentAppId":null}
#
#                   AlternateSignInName               AppDisplayName  \
# 0       neha.kumar@northwindridge.com  Microsoft Office 365 Portal
# 1      sofia.lopez@northwindridge.com              Microsoft Teams
# 2         mei.wang@northwindridge.com      GitHub Enterprise Cloud
# 3     liam.wilson2@northwindridge.com  Microsoft Office 365 Portal
# 4  morgan.gonzalez@northwindridge.com  Microsoft Office 365 Portal
#
# ...
